# %%
from multiplefunctions import multipleFunctions

# %%
multipleFunctions.BMI()
# Out:
# Enter Body mass index:  25
# Over Weight

# %%
multipleFunctions.percentage()
# Out:
# Subject1= 10
# Subject2= 10
# Subject3= 10
# Subject4= 10
# Subject5= 10
# 10.0

# %%
gender = input("Your Gender:")
age = int(input("Your age:"))
message = multipleFunctions.Elegible(gender.upper(), age)
print(message)
# Out:
# Your Gender: male
# Your age: 25
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 3
#       1 gender = input("Your Gender:")
#       2 age = int(input("Your age:"))
# ----> 3 message = multipleFunctions.Elegible(gender.upper(), age)
#       4 print(message)
#
# AttributeError: type object 'multipleFunctions' has no attribute 'Elegible'
