# %%
#1.What is wrong with the following function definition, and how do you fix it?


def say_hello(name)
    print("Hello, " + name)

# %%
def say_hello(name):
    print("Hello, " + name)

# %%
#2.What error will occur in the following code, and how do you fix it?


age = 25
print("I am " + age + " years old")

# %%
age = 25
print("I am " , age , " years old")
# Out:
# I am  25  years old

# %%
#3.Question:
What is the issue with the following code?

def greet():
    message = "Hello"
print(message)

# %%
def greet():
    message = "Hello"
    print(message)

# %%
#4.What error will occur in the following code, and how do you fix it?

def add(a, b):
    return a + b

print(add(5))

# %%
def add(a, b):
    return a + b

print(add(5,2))
# Out:
# 7

# %%
#5.What is wrong with this code?

def is_even(n):
    if n % 2 == 1:
        return True
    else:
        return False

# %%
def is_even(n):
    if n % 2 == 0:
        return True
    else:
        return False

# %%
#6.What happens when you run this code?

num = int("10a")
print(num)

# %%
# cast exception will be thrown

num = int("10")
print(num)
# Out:
# 10

# %%
#7.What will happen when you run the following code?


numbers = [1, 2, 3, 4]
numbers.sort().reverse()
print(numbers)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 5
#       1 #7.What will happen when you run the following code?
#       4 numbers = [1, 2, 3, 4]
# ----> 5 numbers.sort().reverse()
#       6 print(numbers)
#
# AttributeError: 'NoneType' object has no attribute 'reverse'

# %%
#sort() will not return anything, so it will throw error

numbers = [1, 2, 3, 4]
numbers.sort()
numbers.reverse()
print(numbers)
# Out:
# [4, 3, 2, 1]

# %%
#8.What is the issue with this code?


numbers = [1, 2, 3]
numbers = numbers.append(4)
print(numbers)
# Out:
# None

# %%
# append will not return anything, no need to assign it again to numbers
numbers = [1, 2, 3]
numbers.append(4)
print(numbers)
# Out:
# [1, 2, 3, 4]

# %%
#9.What will happen when you run the following code?


count = 10

def increment():
    count += 1
    print(count)

increment()
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[18], line 10
#       7     count += 1
#       8     print(count)
# ---> 10 increment()
#
# Cell In[18], line 7, in increment()
#       6 def increment():
# ----> 7     count += 1
#       8     print(count)
#
# UnboundLocalError: cannot access local variable 'count' where it is not associated with a value

# %%
count = 10

def increment(count):
    count += 1
    print(count)

increment(count)
# Out:
# 11

# %%
#10.What error will occur in the following code?

text = "Python"
print(text[10])

# %%
# index out of bound error, since trying to access beyond the length of the string
text = "Python"
print(text[5])
# Out:
# n
