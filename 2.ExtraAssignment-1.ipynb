# %%
print("HOPE AI")
# Out:
# HOPE AI

# %%
input("Enter your institute name? :")
# Out:
# Enter your institute name? : Hope AI
# 'Hope AI'

# %%
input("Enter your name :")
input("Enter your age :")
input("Enter your school name :")
input("Enter your degree :")
# Out:
# Enter your name : Kamal
# Enter your age : 27
# Enter your school name : SVV
# Enter your degree : B.E
# 'B.E'

# %%
#Addition

# %%
a= int(input("a="))
b= int(input("b="))
add= a+b
print("add=",add)
# Out:
# a= 10
# b= 20
# add= 30

# %%
a= int(input("a="))
b= int(input("b="))
sub= a-b
print("sub=",sub)
# Out:
# a= 10
# b= 20
# sub= -10

# %%
a= int(input("a="))
b= int(input("b="))
mul= a*b
print("Mul=",mul)
# Out:
# a= 10
# b= 20
# Mul= 200

# %%
a= int(input("a="))
b= int(input("b="))
div= a/b
print("Float Div=",div)
# Out:
# a= 76
# b= 31
# Float Div= 2.4516129032258065

# %%
a= int(input("a="))
b= int(input("b="))
div= a/b
print("Power=",pow(a,b))
# Out:
# a= 4
# b= 4
# Power= 256
